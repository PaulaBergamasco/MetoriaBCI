# %% [markdown]
# <a href="https://colab.research.google.com/github/PaulaBergamasco/MetoriaBCI/blob/main/Visualizacion_temporal.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib.dates import DateFormatter
import matplotlib.ticker as ticker

from pandas._libs.tslibs.timestamps import Timestamp

import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df= pd.read_csv('/content/drive/MyDrive/DataFrame_curado.csv')

# %%
df
# Out:
#             Canal1  Canal2      Canal3    Canal4  Stimulus Fuente         STime
# 0       109.920000   80.89  116.700000  25.98000         2    AA0  00:44.030000
# 1        33.200000    6.53   29.670000 -39.15000         2    AA0  00:44.035000
# 2       -20.970000  -38.82  -24.700000 -56.02000         2    AA0  00:44.040000
# 3        59.930000   41.51   67.890000  13.27000         2    AA0  00:44.045000
# 4       109.300000   81.58  113.840000  19.57000         2    AA0  00:44.050000
# ...            ...     ...         ...       ...       ...    ...           ...
# 226394   48.574994   35.28   26.700774  49.36887         2    MA1  05:36.670000
# 226395   53.034994   27.68   34.210774  50.31887         2    MA1  05:36.675000
# 226396   50.024994   38.31   26.930774  45.97887         2    MA1  05:36.680000
# 226397   43.384994   43.12   17.620774  40.18887         2    MA1  05:36.685000
# 226398   55.874994   40.72   31.490774  47.79887         2    MA1  05:36.690000
#
# ...

# %%
AA0 = df[df['Fuente'] == 'AA0']
AA1 = df[df['Fuente'] == 'AA1']
AA2 = df[df['Fuente'] == 'AA2']
HA1 = df[df['Fuente'] == 'HA1']
JA1 = df[df['Fuente'] == 'JA1']
JA2 = df[df['Fuente'] == 'JA2']
MA1 = df[df['Fuente'] == 'MA1']

# %%
AA0.head()
# Out:
#    Canal1  Canal2  Canal3  Canal4  Stimulus Fuente         STime
# 0  109.92   80.89  116.70   25.98         2    AA0  00:44.030000
# 1   33.20    6.53   29.67  -39.15         2    AA0  00:44.035000
# 2  -20.97  -38.82  -24.70  -56.02         2    AA0  00:44.040000
# 3   59.93   41.51   67.89   13.27         2    AA0  00:44.045000
# 4  109.30   81.58  113.84   19.57         2    AA0  00:44.050000

# %% [markdown]
# # Un sujeto todos los canales

# %%
HA1_1seg = HA1[(HA1['STime'] >= '01:21.955000') & (HA1['STime'] <= '01:31.955000')]
HA1_1seg
# Out:
#             Canal1      Canal2      Canal3  ...  Stimulus  Fuente         STime
# 121730 -107.445979  -76.305374 -119.840736  ...         2     HA1  01:21.955000
# 121731  -79.355979  -64.045374 -108.160736  ...         2     HA1  01:21.960000
# 121732 -105.895979  -97.865374 -124.790736  ...         2     HA1  01:21.965000
# 121733 -143.745979 -141.815374 -149.380736  ...         2     HA1  01:21.970000
# 121734 -106.555979  -86.645374 -120.970736  ...         2     HA1  01:21.975000
# ...            ...         ...         ...  ...       ...     ...           ...
# 123636 -193.605979 -248.255374 -166.220736  ...         2     HA1  01:31.485000
# 123637 -189.245979 -241.735374 -169.080736  ...         2     HA1  01:31.490000
# 123638 -165.715979 -232.175374 -139.710736  ...         2     HA1  01:31.495000
# 123639 -188.405979 -243.965374 -157.750736  ...         2     HA1  01:31.500000
# 123640 -182.165979 -230.725374 -146.890736  ...         2     HA1  01:31.505000
#
# ...

# %%
nrows = 4
fig, ax = plt.subplots(nrows, figsize=(20,10))
fig.patch.set_facecolor('white')

ax[0].plot(HA1_1seg.STime, HA1_1seg.Canal1, label = 'CH1')
ax[1].plot(HA1_1seg.STime, HA1_1seg.Canal2, label = 'CH2', color = 'red')
ax[2].plot(HA1_1seg.STime, HA1_1seg.Canal3, label = 'CH3', color = 'green')
ax[3].plot(HA1_1seg.STime, HA1_1seg.Canal4, label = 'CH4', color = 'orange')
for i in range(nrows):
    ax[i].xaxis.set_major_locator(ticker.AutoLocator())
plt.show()

# %%
nrows = 4
fig, ax = plt.subplots(nrows, figsize=(20,10))
fig.patch.set_facecolor('white')

ax[0].plot(HA1.STime.sample(2000), HA1.Canal1.sample(2000), label = 'CH1')
ax[1].plot(HA1.STime.sample(2000), HA1.Canal2.sample(2000), label = 'CH2', color = 'red')
ax[2].plot(HA1.STime.sample(2000), HA1.Canal3.sample(2000), label = 'CH3', color = 'green')
ax[3].plot(HA1.STime.sample(2000), HA1.Canal4.sample(2000), label = 'CH4', color = 'orange')
for i in range(nrows):
    ax[i].xaxis.set_major_locator(ticker.AutoLocator())
plt.show()

# %%
nrows = 4
fig, ax = plt.subplots(nrows, figsize=(20,10))
fig.patch.set_facecolor('white')

ax[0].plot(HA1.STime, HA1.Canal1, label = 'CH1')
ax[1].plot(HA1.STime, HA1.Canal2, label = 'CH2', color = 'red')
ax[2].plot(HA1.STime, HA1.Canal3, label = 'CH3', color = 'green')
ax[3].plot(HA1.STime, HA1.Canal4, label = 'CH4', color = 'orange')
for i in range(nrows):
    ax[i].xaxis.set_major_locator(ticker.AutoLocator())
plt.show()

# %% [markdown]
# # Un mismo canal todos los sujetos

# %%
AA0_1seg = AA0[(AA0['STime'] >= '00:44.030000') & (AA0['STime'] <= '00:54.030000')]
AA1_1seg = AA1[(AA1['STime'] >= '01:13.065000') & (AA1['STime'] <= '01:23.065000')]
AA2_1seg = AA2[(AA2['STime'] >= '02:45.790000') & (AA2['STime'] <= '02:55.790000')]
HA1_1seg = HA1[(HA1['STime'] >= '01:21.955000') & (HA1['STime'] <= '01:31.955000')]
JA1_1seg = JA1[(JA1['STime'] >= '01:18.140000') & (JA1['STime'] <= '01:28.140000')]
JA2_1seg = JA2[(JA2['STime'] >= '00:53.560000') & (JA2['STime'] <= '01:03.560000')]
MA1_1seg = MA1[(MA1['STime'] >= '01:20.875000') & (MA1['STime'] <= '01:30.875000')]

# %%
nrows =7
fig, ax = plt.subplots(nrows, figsize=(20,12))
fig.patch.set_facecolor('white')

ax[0].plot(AA0_1seg.STime, AA0_1seg.Canal3)
ax[1].plot(AA1_1seg.STime, AA1_1seg.Canal3, color = 'red')
ax[2].plot(AA2_1seg.STime, AA2_1seg.Canal3, color = 'black')
ax[3].plot(HA1_1seg.STime, HA1_1seg.Canal3, color = 'green')
ax[4].plot(JA1_1seg.STime, JA1_1seg.Canal3, color = 'cyan')
ax[5].plot(JA2_1seg.STime, JA2_1seg.Canal3, color = 'orange')
ax[6].plot(MA1_1seg.STime, MA1_1seg.Canal3, color = 'pink')
for i in range(nrows):
    ax[i].xaxis.set_major_locator(ticker.AutoLocator())

plt.show()

# %%
nrows =7
fig, ax = plt.subplots(nrows, figsize=(20,12))
fig.patch.set_facecolor('white')

ax[0].plot(AA0.STime.sample(2000), AA0.Canal3.sample(2000))
ax[1].plot(AA1.STime.sample(2000), AA1.Canal3.sample(2000), color = 'red')
ax[2].plot(AA2.STime.sample(2000), AA2.Canal3.sample(2000), color = 'black')
ax[3].plot(HA1.STime.sample(2000), HA1.Canal3.sample(2000), color = 'green')
ax[4].plot(JA1.STime.sample(2000), JA1.Canal3.sample(2000), color = 'cyan')
ax[5].plot(JA2.STime.sample(2000), JA2.Canal3.sample(2000), color = 'orange')
ax[6].plot(MA1.STime.sample(2000), MA1.Canal3.sample(2000), color = 'pink')
for i in range(nrows):
    ax[i].xaxis.set_major_locator(ticker.AutoLocator())

plt.show()

# %%
nrows =7
fig, ax = plt.subplots(nrows, figsize=(20,12))
fig.patch.set_facecolor('white')

ax[0].plot(AA0.STime, AA0.Canal3)
ax[1].plot(AA1.STime, AA1.Canal3, color = 'red')
ax[2].plot(AA2.STime, AA2.Canal3, color = 'black')
ax[3].plot(HA1.STime, HA1.Canal3, color = 'green')
ax[4].plot(JA1.STime, JA1.Canal3, color = 'cyan')
ax[5].plot(JA2.STime, JA2.Canal3, color = 'orange')
ax[6].plot(MA1.STime, MA1.Canal3, color = 'pink')
for i in range(nrows):
    ax[i].xaxis.set_major_locator(ticker.AutoLocator())

plt.show()

# %% [markdown]
# # Mismo canal, mismo sujeto, diferentes sesiones

# %%
JA1_1seg = JA1[(JA1['STime'] >= '01:18.140000') & (JA1['STime'] <= '01:28.140000')]
JA2_1seg = JA2[(JA2['STime'] >= '00:53.560000') & (JA2['STime'] <= '01:03.560000')]

# %%
nrows =2
fig, ax = plt.subplots(nrows, figsize=(20,8))
fig.patch.set_facecolor('white')

ax[0].plot(JA1_1seg.STime, JA1_1seg.Canal4)
ax[1].plot(JA2_1seg.STime, JA2_1seg.Canal4, color = 'red')
for i in range(nrows):
    ax[i].xaxis.set_major_locator(ticker.AutoLocator())
plt.show()

# %%
nrows =2
fig, ax = plt.subplots(nrows, figsize=(20,8))
fig.patch.set_facecolor('white')

ax[0].plot(JA1.STime.sample(2000), JA1.Canal4.sample(2000))
ax[1].plot(JA2.STime.sample(2000), JA2.Canal4.sample(2000), color = 'red')
for i in range(nrows):
    ax[i].xaxis.set_major_locator(ticker.AutoLocator())
plt.show()

# %%
nrows =2
fig, ax = plt.subplots(nrows, figsize=(20,8))
fig.patch.set_facecolor('white')

ax[0].plot(JA1.STime, JA1.Canal4)
ax[1].plot(JA2.STime, JA2.Canal4, color = 'red')
for i in range(nrows):
    ax[i].xaxis.set_major_locator(ticker.AutoLocator())
plt.show()

# %% [markdown]
# # Mismo Sujeto y canal - Diferentes estados

# %%
JA1_estado1 = JA1[JA1['Stimulus'] == 1]
JA1_estado1
# Out:
#           Canal1     Canal2     Canal3  ...  Stimulus  Fuente         STime
# 159782 -30.60323 -31.481456 -30.467642  ...         1     JA1  01:18.140000
# 159783 -37.86323 -33.901456 -35.207642  ...         1     JA1  01:18.145000
# 159784 -38.54323 -38.981456 -35.077642  ...         1     JA1  01:18.150000
# 159785 -25.32323 -38.561456 -31.367642  ...         1     JA1  01:18.155000
# 159786 -32.08323 -30.091456 -26.927642  ...         1     JA1  01:18.160000
# ...          ...        ...        ...  ...       ...     ...           ...
# 182919  45.54677  55.328544  43.782358  ...         1     JA1  04:20.795000
# 182920  61.89677  56.138544  40.692358  ...         1     JA1  04:20.800000
# 182921  45.66677  48.628544  38.052358  ...         1     JA1  04:20.805000
# 182922  44.85677  45.188544  34.552358  ...         1     JA1  04:20.810000
# 182923  57.08677  54.638544  43.482358  ...         1     JA1  04:20.815000
#
# [12630 rows x 7 columns]

# %%
JA1_estado2 = JA1[JA1['Stimulus'] == 2]
JA1_estado2
# Out:
#           Canal1     Canal2     Canal3  ...  Stimulus  Fuente         STime
# 161889 -24.09323 -28.061456 -16.097642  ...         2     JA1  01:36.220000
# 161890 -13.82323 -22.931456 -14.317642  ...         2     JA1  01:36.225000
# 161891 -28.48323 -29.271456 -18.297642  ...         2     JA1  01:36.230000
# 161892 -35.35323 -35.401456 -23.007642  ...         2     JA1  01:36.235000
# 161893 -24.73323 -31.471456 -18.547642  ...         2     JA1  01:36.240000
# ...          ...        ...        ...  ...       ...     ...           ...
# 185018  50.32677  51.968544  38.182358  ...         2     JA1  04:37.500000
# 185019  42.33677  49.608544  36.522358  ...         2     JA1  04:37.505000
# 185020  49.68677  54.408544  41.952358  ...         2     JA1  04:37.510000
# 185021  55.29677  56.898544  43.762358  ...         2     JA1  04:37.515000
# 185022  34.77677  52.788544  42.452358  ...         2     JA1  04:37.520000
#
# [12611 rows x 7 columns]

# %%
JA1_estado1_1 = JA1_estado1[(JA1_estado1['STime'] >= '01:18.140000')
                           & (JA1_estado1['STime'] <= '01:28.140000')]

JA1_estado2_2 = JA1_estado2[(JA1_estado2['STime'] >= '01:36.220000') 
               & (JA1_estado2['STime'] <= '01:46.220000')]

# %%
nrows =2
fig, ax = plt.subplots(nrows, figsize=(20,8))
fig.patch.set_facecolor('white')

ax[0].plot(JA1_estado1_1.STime, JA1_estado1_1.Canal4)
ax[1].plot(JA1_estado2_2.STime, JA1_estado2_2.Canal4, color = 'red')
for i in range(nrows):
    ax[i].xaxis.set_major_locator(ticker.AutoLocator())
plt.show()

# %%
nrows =2
fig, ax = plt.subplots(nrows, figsize=(20,8))
fig.patch.set_facecolor('white')

ax[0].plot(JA1_estado1.STime.sample(2000), JA1_estado1.Canal4.sample(2000))
ax[1].plot(JA1_estado2.STime.sample(2000), JA1_estado2.Canal4.sample(2000), color = 'red')
for i in range(nrows):
    ax[i].xaxis.set_major_locator(ticker.AutoLocator())
plt.show()

# %%
nrows =2
fig, ax = plt.subplots(nrows, figsize=(20,8))
fig.patch.set_facecolor('white')

ax[0].plot(JA1_estado1.STime, JA1_estado1.Canal4)
ax[1].plot(JA1_estado2.STime, JA1_estado2.Canal4, color = 'red')
for i in range(nrows):
    ax[i].xaxis.set_major_locator(ticker.AutoLocator())
plt.show()

# %% [markdown]
# # Mismo estado - Diferentes Suejtos

# %%
JA1_estado2
# Out:
#           Canal1     Canal2     Canal3  ...  Stimulus  Fuente         STime
# 161889 -24.09323 -28.061456 -16.097642  ...         2     JA1  01:36.220000
# 161890 -13.82323 -22.931456 -14.317642  ...         2     JA1  01:36.225000
# 161891 -28.48323 -29.271456 -18.297642  ...         2     JA1  01:36.230000
# 161892 -35.35323 -35.401456 -23.007642  ...         2     JA1  01:36.235000
# 161893 -24.73323 -31.471456 -18.547642  ...         2     JA1  01:36.240000
# ...          ...        ...        ...  ...       ...     ...           ...
# 185018  50.32677  51.968544  38.182358  ...         2     JA1  04:37.500000
# 185019  42.33677  49.608544  36.522358  ...         2     JA1  04:37.505000
# 185020  49.68677  54.408544  41.952358  ...         2     JA1  04:37.510000
# 185021  55.29677  56.898544  43.762358  ...         2     JA1  04:37.515000
# 185022  34.77677  52.788544  42.452358  ...         2     JA1  04:37.520000
#
# [12611 rows x 7 columns]

# %%
AA1_estado2 = AA1[AA1['Stimulus'] == 2]
AA1_estado2 = AA1_estado2[(AA1_estado2['STime'] >= '01:13.065000')
                           & (AA1_estado2['STime'] <= '01:23.065000')]
AA1_estado2
# Out:
#            Canal1      Canal2      Canal3  ...  Stimulus  Fuente         STime
# 29448  -37.024893 -138.056675 -122.283585  ...         2     AA1  01:13.065000
# 29449  108.245107   16.443325   38.976415  ...         2     AA1  01:13.070000
# 29450  163.425107   72.623325  122.596415  ...         2     AA1  01:13.075000
# 29451   56.715107  -42.606675    1.396415  ...         2     AA1  01:13.080000
# 29452  -15.194893 -128.536675 -105.153585  ...         2     AA1  01:13.085000
# ...           ...         ...         ...  ...       ...     ...           ...
# 31444   87.115107   -3.116675   20.026415  ...         2     AA1  01:23.045000
# 31445  140.885107   62.693325  107.736415  ...         2     AA1  01:23.050000
# 31446   35.435107  -51.296675  -13.043585  ...         2     AA1  01:23.055000
# 31447  -51.884893 -145.016675 -133.413585  ...         2     AA1  01:23.060000
# 31448   86.055107    2.203325   19.136415  ...         2     AA1  01:23.065000
#
# [2001 rows x 7 columns]

# %%
MA1_estado2 = MA1[MA1['Stimulus'] == 2]
MA1_estado2 = MA1_estado2[(MA1_estado2['STime'] >= '01:40.150000')
                           & (MA1_estado2['STime'] <= '01:50.150000')]
MA1_estado2
# Out:
#            Canal1  Canal2     Canal3    Canal4  Stimulus Fuente         STime
# 203249 -19.775006    6.39 -26.019226 -35.05113         2    MA1  01:40.150000
# 203250 -20.535006   16.79 -25.369226 -36.36113         2    MA1  01:40.155000
# 203251 -19.725006   20.29 -23.599226 -31.15113         2    MA1  01:40.160000
# 203252 -24.685006    5.76 -19.859226 -37.25113         2    MA1  01:40.165000
# 203253 -21.425006    7.03 -25.549226 -36.03113         2    MA1  01:40.170000
# ...           ...     ...        ...       ...       ...    ...           ...
# 205245  -3.055006   27.74 -23.989226 -20.29113         2    MA1  01:50.130000
# 205246  -5.415006   29.02 -27.919226 -24.33113         2    MA1  01:50.135000
# 205247  -2.925006   39.07 -21.459226 -21.95113         2    MA1  01:50.140000
# 205248  -2.925006   31.98 -22.149226 -21.09113         2    MA1  01:50.145000
# 205249 -10.935006   14.71 -32.059226 -30.58113         2    MA1  01:50.150000
#
# [2001 rows x 7 columns]

# %%
nrows =3
fig, ax = plt.subplots(nrows, figsize=(20,10))
fig.patch.set_facecolor('white')

ax[0].plot(JA1_estado2.STime, JA1_estado2.Canal4)
ax[1].plot(AA1_estado2.STime, AA1_estado2.Canal4, color = 'red')
ax[2].plot(MA1_estado2.STime, MA1_estado2.Canal4, color = 'green')
for i in range(nrows):
    ax[i].xaxis.set_major_locator(ticker.AutoLocator())
plt.show()

# %%
nrows =3
fig, ax = plt.subplots(nrows, figsize=(20,10))
fig.patch.set_facecolor('white')

ax[0].plot(JA1.STime.sample(2000), JA1.Canal4.sample(2000))
ax[1].plot(AA1.STime.sample(2000), AA1.Canal4.sample(2000), color = 'red')
ax[2].plot(MA1.STime.sample(2000), MA1.Canal4.sample(2000), color = 'green')
for i in range(nrows):
    ax[i].xaxis.set_major_locator(ticker.AutoLocator())
plt.show()

# %%
nrows =3
fig, ax = plt.subplots(nrows, figsize=(20,10))
fig.patch.set_facecolor('white')

ax[0].plot(JA1.STime, JA1.Canal4)
ax[1].plot(AA1.STime, AA1.Canal4, color = 'red')
ax[2].plot(MA1.STime, MA1.Canal4, color = 'green')
for i in range(nrows):
    ax[i].xaxis.set_major_locator(ticker.AutoLocator())
plt.show()
